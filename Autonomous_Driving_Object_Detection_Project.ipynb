# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshira/Deep-Learning/blob/main/Autonomous_Driving_Object_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem Statement:
# ##Autonomous vehicles (AV) and intelligent transport systems (ITS) are the future of road transport. Automatic detection of vehicles on the road in real-time is essential for vehicle tracking, vehicle counting, and road incident response.

# %%
# --- Import Libraries ---
import os
import cv2
import PIL
import glob
import shutil
import random
import requests
import zipfile
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#!rm -r '/content/Images'
#!rm -r '/content/yolov5'

# %%
# --- Unzip the images to train ---
# !unzip -q '/content/drive/MyDrive/------/Autonomous Driving/Images.zip'

# %%
# --- Set variable for labels csv path ---
labels = ('/content/drive/MyDrive/------/Autonomous Driving/labels.csv')

# %%
# --- Read the dataset ---
label = pd.read_csv(labels)
label.head(10)
# Out:
#    00000000       pickup_truck  213   34  255   50
# 0         0                car  194   78  273  122
# 1         0                car  155   27  183   35
# 2         0  articulated_truck   43   25  109   55
# 3         0                car  106   32  124   45
# 4         1                bus  205  155  568  314
# 5         1                bus  285  123  477  168
# 6         1                car  544  162  617  193
# 7         1                car  329  152  371  163
# 8         1                car  447  161  497  183
# 9         1                car  662  199  715  236

# %%
# --- Inspect data ---
label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351548 entries, 0 to 351547
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   00000000      351548 non-null  int64
#  1   pickup_truck  351548 non-null  object
#  2   213           351548 non-null  int64
#  3   34            351548 non-null  int64
#  4   255           351548 non-null  int64
#  5   50            351548 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 16.1+ MB

# %%
# --- Inspect data ---
view = label['pickup_truck'].unique()
view
# Out:
# array(['car', 'articulated_truck', 'bus', 'motorized_vehicle',
#        'pickup_truck', 'work_van', 'single_unit_truck', 'pedestrian',
#        'bicycle', 'non-motorized_vehicle', 'motorcycle'], dtype=object)

# %%
# --- Add column names to data ---
col_names = ['index', 'class_name', 'xmin', 'ymin', 'xmax', 'ymax']

label = pd.read_csv(labels, names=col_names)
label.head(10)
# Out:
#    index         class_name  xmin  ymin  xmax  ymax
# 0      0       pickup_truck   213    34   255    50
# 1      0                car   194    78   273   122
# 2      0                car   155    27   183    35
# 3      0  articulated_truck    43    25   109    55
# 4      0                car   106    32   124    45
# 5      1                bus   205   155   568   314
# 6      1                bus   285   123   477   168
# 7      1                car   544   162   617   193
# 8      1                car   329   152   371   163
# 9      1                car   447   161   497   183

# %%
#!rm -r '/content/yolo_dataset'

# %%
#!rm -r '/content/yolov5'

# %% [markdown]
# # Creating Python script for the following
#
#
# 1.   Creates train, test and valid directories
# 2.   Clones the Yolov5 to yolov5 local directory
# 3.   Reads and processes your labels.csv: It takes your raw bounding box data.
# 4.   Splits the image IDs: It divides your dataset's image IDs into distinct train, test, and validation sets based on the ratios you defined.
# 5.   Copies images: It copies the actual image files into the newly created images/train, images/test, images/valid directories.
# 6.  Converts and Writes YOLO Labels: This is a crucial step! It reads the bounding box coordinates from your CSV, converts them into the normalized YOLO format (class_id, center_x, center_y, width, height), and writes them to .txt files in the labels/train, labels/test, labels/valid directories.
# 7.   Generates data.yaml: It dynamically creates the data.yaml configuration file that YOLOv5 needs to understand your dataset's structure, class names, and paths.
# 8.  Runs YOLOv5 Training: It executes the train.py script from the cloned YOLOv5 repository, using your data.yaml and pre-trained weights, to train the object detection model on your custom dataset. It also uses the GPU (--device 0) and a specified batch size.
# 9. Shows Validation Prediction Images: After training, it displays a limited number of prediction images from the validation set, showing how the model performed during training
# 10. Runs YOLOv5 Inference on Test Data: It executes the detect.py script on the test portion of your dataset, applying the trained model to find objects.
#
# 11.  Visualizes Inference Results: It displays a limited number of images from the inference run, showing the detected objects with bounding boxes and confidence scores.

# %%
# %%writefile /content/split_dataset.py
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
import glob
import cv2
import matplotlib.pyplot as plt

# --- Setting configuration ---
IMAGE_DIR = '/content/Images'
LABELS_CSV_PATH = '/content/drive/MyDrive/Colab Notebooks/Simplilearn Projects/Autonomous Driving/labels.csv'
OUTPUT_BASE_DIR = 'yolo_dataset'

TRAIN_RATIO = 0.8
TEST_RATIO = 0.1
VALID_RATIO = 0.1

RANDOM_SEED = 42
epochs = 5

# --- Class name mapping ---
CLASS_NAMES = ['car', 'articulated_truck', 'bus', 'motorized_vehicle',
               'pickup_truck', 'work_van', 'single_unit_truck', 'pedestrian',
               'bicycle', 'non-motorized_vehicle', 'motorcycle']
class_name_to_id = {name: i for i, name in enumerate(CLASS_NAMES)}

# --- Create Output Directories for your split dataset ---
def create_split_dataset_dirs(base_dir, subfolders=['train', 'test', 'valid']):
    base_images_path = os.path.join(base_dir, 'images')
    base_labels_path = os.path.join(base_dir, 'labels')
    os.makedirs(base_images_path, exist_ok=True)
    os.makedirs(base_labels_path, exist_ok=True)
    print(f"Created base images dir: {base_images_path} exists: {os.path.exists(base_images_path)}")
    print(f"Created base labels dir: {base_labels_path} exists: {os.path.exists(base_labels_path)}")
    for folder in subfolders:
        img_path = os.path.join(base_dir, 'images', folder)
        lbl_path = os.path.join(base_dir, 'labels', folder)
        os.makedirs(img_path, exist_ok=True)
        os.makedirs(lbl_path, exist_ok=True)
        print(f"Created {folder}/images dir: {img_path} exists: {os.path.exists(img_path)}")
        print(f"Created {folder}/labels dir: {lbl_path} exists: {os.path.exists(lbl_path)}")


# --- Helper function to convert and write YOLO labels ---
def convert_and_write_yolo_labels(image_id, group_df, dest_label_path, image_width, image_height):
    """
    Converts bounding box data from DataFrame row to YOLO format and writes to file.
    """
    with open(dest_label_path, 'w') as f:
        for _, row in group_df.iterrows():
            class_name = row['class_name']
            xmin = row['xmin']
            ymin = row['ymin']
            xmax = row['xmax']
            ymax = row['ymax']

            class_id = class_name_to_id.get(class_name, -1)
            if class_id == -1:
                print(f"Warning: Unknown class '{class_name}' for image {image_id}. Skipping bounding box.")
                continue

            # Convert (xmin, ymin, xmax, ymax) to (center_x, center_y, width, height)
            box_width = xmax - xmin
            box_height = ymax - ymin
            center_x = xmin + (box_width / 2)
            center_y = ymin + (box_height / 2)

            # Normalize coordinates
            norm_center_x = center_x / image_width
            norm_center_y = center_y / image_height
            norm_width = box_width / image_width
            norm_height = box_height / image_height

            f.write(f'{class_id} {norm_center_x:.6f} {norm_center_y:.6f} {norm_width:.6f} {norm_height:.6f}\n')

# --- Function to find the latest YOLOv5 experiment results directory ---

def get_latest_yolov5_run_dir():
    runs_train_base = os.path.join(os.getcwd(), 'runs', 'train') # /content/yolov5/runs/train
    if not os.path.exists(runs_train_base):
        print(f"Warning: YOLOv5 runs/train directory not found at {runs_train_base}")
        return None

    exp_dirs = [d for d in os.listdir(runs_train_base) if d.startswith('exp') and os.path.isdir(os.path.join(runs_train_base, d))]
    if not exp_dirs:
        print(f"No 'exp' directories found in {runs_train_base}. Check if training created a custom-named directory.")
        return None

    # Sort numerically (exp1, exp2, exp10) and pick the last one
    exp_dirs.sort(key=lambda x: int(x.replace('exp', '')) if x.replace('exp', '').isdigit() else 0)
    latest_exp_dir_name = exp_dirs[-1]

    return os.path.join(runs_train_base, latest_exp_dir_name)

# --- Define a function to show validation predictions saved during training ---
def show_validation_images(yolov5_results_dir, limit=3): # Renamed parameter for clarity
  if not yolov5_results_dir or not os.path.exists(yolov5_results_dir):
      print(f"Error: YOLOv5 results directory not found or invalid: {yolov5_results_dir}")
      return

  print(f"Attempting to list contents of: {yolov5_results_dir}")
  #os.system(f'ls "{yolov5_results_dir}"')

  EXPORT_PATH = yolov5_results_dir
  validation_pred_images = glob.glob(f"{EXPORT_PATH}/*_pred.jpg")
  print(f"Found validation prediction images: {len(validation_pred_images)}")

  if not validation_pred_images:
      print(f"No *_pred.jpg images found in {EXPORT_PATH}. Double-check YOLOv5's output.")
      return

  images_to_display = validation_pred_images[:limit]
  print(f"Displaying the {len(images_to_display)} images out of {len(validation_pred_images)}.")

  for pred_image in images_to_display:
    image = cv2.imread(pred_image)
    if image is not None:
        plt.figure(figsize=(10, 10))
        plt.imshow(image[:, :, ::-1])
        plt.axis('off')
        plt.title(os.path.basename(pred_image))
        plt.show()
    else:
        print(f"Warning: Could not read image {pred_image}. It might be corrupted or not a valid image file.")

# --- Define a helper function for inference on images ---
def inference(yolov5_results_dir, data_path): # Renamed parameter for clarity
    if not yolov5_results_dir:
        print("Error: YOLOv5 results directory is not valid for inference.")
        return

    infer_base_dir = os.path.join(os.getcwd(), 'runs', 'detect') # /content/yolov5/runs/detect
    os.makedirs(infer_base_dir, exist_ok=True) # Ensure it exists

    infer_dir_count = len([d for d in os.listdir(infer_base_dir) if os.path.isdir(os.path.join(infer_base_dir, d))])
    print(f"Current number of inference directories {infer_dir_count}")
    INFER_NAME = f"inference_{infer_dir_count+1}" # This is the name for the output folder

    # Path to best.pt weights
    weights_path = os.path.join(yolov5_results_dir, 'weights', 'best.pt')
    if not os.path.exists(weights_path):
        print(f"Error: best.pt weights not found at {weights_path}. Check training output.")
        return

    print(f"Running inference, output will be in: {os.path.join(infer_base_dir, INFER_NAME)}")
    os.system(f'python3 detect.py --weights "{weights_path}" '
          f'--source "{data_path}" --name "{INFER_NAME}" --project "{infer_base_dir}" --exist-ok')

    return os.path.join(infer_base_dir, INFER_NAME) # Return the full path to the inference results

# --- Visualize inference images ---
def visualize_inference_images(INFER_RESULTS_DIR, limit=3): # Renamed parameter for clarity
    if not INFER_RESULTS_DIR or not os.path.exists(INFER_RESULTS_DIR):
        print(f"Error: Inference results directory not found or invalid: {INFER_RESULTS_DIR}")
        return

    print(f"Attempting to visualize images from: {INFER_RESULTS_DIR}")
    infer_images = glob.glob(f"{INFER_RESULTS_DIR}/*.jpg")
    print(f"Found inference images: {len(infer_images)}")

    if not infer_images:
        print(f"No .jpg images found in {INFER_RESULTS_DIR}.")
        return

    images_to_display = infer_images[:limit]
    print(f"Displaying the {len(images_to_display)} images out of {len(infer_images)}.")

    for pred_image in images_to_display:
        image = cv2.imread(pred_image)
        if image is not None:
            plt.figure(figsize=(10, 10))
            plt.imshow(image[:, :, ::-1])
            plt.axis('off')
            plt.title(os.path.basename(pred_image))
            plt.show()
        else:
            print(f"Warning: Could not read image {pred_image}.")


# --- Main Execution Flow ---
if __name__ == "__main__":
    # Ensure all necessary libraries are installed
    if not os.path.exists('/content/yolov5'):
        os.system('git clone https://github.com/ultralytics/yolov5.git /content/yolov5') # Clone to /content/yolov5
    os.chdir('/content/yolov5') # Ensure you are in the yolov5 directory
    os.system('pip install -r requirements.txt')


    # Create your custom dataset split directories first
    # This was originally `create_dirs(OUTPUT_BASE_DIR)`, changed to `create_split_dataset_dirs`
    # for consistent naming as defined above.
    create_split_dataset_dirs(OUTPUT_BASE_DIR)

    # --- Your data splitting logic ---
    try:
        col_names = ['index', 'class_name', 'xmin', 'ymin', 'xmax', 'ymax']
        labels_df = pd.read_csv(LABELS_CSV_PATH, names=col_names)
        print(f"Successfully loaded labels from: {LABELS_CSV_PATH}")
    except Exception as e:
        print(f"Error loading CSV for splitting: {e}")
        exit()

    unique_image_ids = labels_df['index'].unique()
    if len(unique_image_ids) == 0:
        print("No unique image IDs found. Exiting dataset split.")
        exit()

    train_ids, temp_ids = train_test_split(unique_image_ids, test_size=(TEST_RATIO + VALID_RATIO), random_state=RANDOM_SEED, shuffle=True)
    test_ids, valid_ids = train_test_split(temp_ids, test_size=(VALID_RATIO / (TEST_RATIO + VALID_RATIO)), random_state=RANDOM_SEED, shuffle=True)

    split_datasets = {'train': train_ids, 'test': test_ids, 'valid': valid_ids}

    for split_name, ids_list in split_datasets.items():
        print(f"\nProcessing {split_name} dataset...")
        for image_id in ids_list:
            image_filename = f'{image_id:08d}.jpg'
            source_image_path = os.path.join(IMAGE_DIR, image_filename)

            dest_image_dir = os.path.join(OUTPUT_BASE_DIR, 'images', split_name)
            dest_label_dir = os.path.join(OUTPUT_BASE_DIR, 'labels', split_name)
            dest_image_path = os.path.join(dest_image_dir, image_filename)
            dest_label_path = os.path.join(dest_label_dir, f'{image_id:08d}.txt')

            if not os.path.exists(source_image_path):
                print(f"Warning: Image not found: {source_image_path}. Skipping.")
                continue

            try:
                with Image.open(source_image_path) as img:
                    image_width, image_height = img.size
            except Exception as e:
                print(f"Error reading image dimensions for {source_image_path}: {e}. Skipping.")
                continue

            shutil.copy(source_image_path, dest_image_path)
            print(f"Copied image {image_filename} to {dest_image_path}. Exists: {os.path.exists(dest_image_path)}")
            image_labels_df = labels_df[labels_df['index'] == image_id]
            convert_and_write_yolo_labels(image_id, image_labels_df, dest_label_path, image_width, image_height)
            print(f"Wrote label {f'{image_id:08d}.txt'} to {dest_label_path}. Exists: {os.path.exists(dest_label_path)}")
    print("\nDataset splitting and YOLO label generation complete!")
    print(f"Check your '{OUTPUT_BASE_DIR}' directory.")


    # --- Prepare data.yaml for YOLOv5 ---
    data_yaml_content = f"""
    path: ./yolo_dataset
    train: images/train
    val: images/valid
    test: images/test

    nc: {len(CLASS_NAMES)}
    names: {CLASS_NAMES}
    """
    DATA_YAML_PATH = '../data.yaml'
    with open(DATA_YAML_PATH, 'w') as f:
        f.write(data_yaml_content)
    print(f"\nCreated data.yaml at {DATA_YAML_PATH}")
    print(data_yaml_content)


    # --- Run YOLOv5 training ---
    YOLO_TRAIN_NAME = 'my_custom_run'
    print(f"\nStarting YOLOv5 training. Results will be in runs/train/{YOLO_TRAIN_NAME} (relative to /content/yolov5)")
    os.system(f'python3 train.py --data {DATA_YAML_PATH} --weights yolov5s.pt '
              f'--img 320 --epochs {epochs} --batch-size 32 --name {YOLO_TRAIN_NAME} --project runs/train --device 0')

    # --- After Training: Get the actual YOLOv5 results directory ---

    ACTUAL_YOLOV5_TRAIN_RESULTS_DIR = os.path.join(os.getcwd(), 'runs', 'train', YOLO_TRAIN_NAME)
    if not os.path.exists(ACTUAL_YOLOV5_TRAIN_RESULTS_DIR):
        ACTUAL_YOLOV5_TRAIN_RESULTS_DIR = get_latest_yolov5_run_dir()
    print(f"Actual YOLOv5 training results directory: {ACTUAL_YOLOV5_TRAIN_RESULTS_DIR}")


    # --- Show Validation Images ---
    show_validation_images(ACTUAL_YOLOV5_TRAIN_RESULTS_DIR)

    # --- Run Inference ---

    relative_inference_source_path = os.path.join(OUTPUT_BASE_DIR, 'images', 'test')
    ABSOLUTE_INFERENCE_SOURCE_PATH = os.path.abspath(relative_inference_source_path)

    if not os.path.exists(ABSOLUTE_INFERENCE_SOURCE_PATH):
        print(f"Critical Error: Inference source path not found: {ABSOLUTE_INFERENCE_SOURCE_PATH}")
        print("Please ensure your 'yolo_dataset' and its 'test/images' folder are correctly set up.")
        ACTUAL_YOLOV5_INFER_RESULTS_DIR =None
    else:
        print(f"Inference source path CONFIRMED to exist: {ABSOLUTE_INFERENCE_SOURCE_PATH}")

    print(f"\nRunning inference on test images from: {ABSOLUTE_INFERENCE_SOURCE_PATH}")
    ACTUAL_YOLOV5_INFER_RESULTS_DIR = inference(ACTUAL_YOLOV5_TRAIN_RESULTS_DIR, ABSOLUTE_INFERENCE_SOURCE_PATH)

    # --- Visualize Inference Images ---
    if ACTUAL_YOLOV5_INFER_RESULTS_DIR:
        visualize_inference_images(ACTUAL_YOLOV5_INFER_RESULTS_DIR, limit=3)
    else:
        print("Inference results directory not found for visualization.")

    print("\nScript execution finished!")
# Out:
# Overwriting /content/split_dataset.py

# %%
# !python /content/split_dataset.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Warning: Image not found: /content/Images/00060812.jpg. Skipping.
# Warning: Image not found: /content/Images/00106563.jpg. Skipping.
# Warning: Image not found: /content/Images/00080463.jpg. Skipping.
# Warning: Image not found: /content/Images/00092580.jpg. Skipping.
# Warning: Image not found: /content/Images/00082952.jpg. Skipping.
# Warning: Image not found: /content/Images/00087004.jpg. Skipping.
# Warning: Image not found: /content/Images/00028479.jpg. Skipping.
# Warning: Image not found: /content/Images/00057043.jpg. Skipping.
# Warning: Image not found: /content/Images/00087637.jpg. Skipping.
# Warning: Image not found: /content/Images/00016763.jpg. Skipping.
# Warning: Image not found: /content/Images/00051885.jpg. Skipping.
# Warning: Image not found: /content/Images/00015616.jpg. Skipping.
# Warning: Image not found: /content/Images/00103835.jpg. Skipping.
# Warning: Image not found: /content/Images/00072672.jpg. Skipping.
# Warning: Image not found: /content/Images/00083073.jpg. Skipping.
# Warning: Image not found: /content/Images/00083151.jpg. Skipping.
# Warning: Image not found: /content/Images/00062981.jpg. Skipping.
# Warning: Image not found: /content/Images/00034195.jpg. Skipping.
# Warning: Image not found: /content/Images/00058628.jpg. Skipping.
# Warning: Image not found: /content/Images/00052247.jpg. Skipping.
# Warning: Image not found: /content/Images/00040754.jpg. Skipping.
# Warning: Image not found: /content/Images/00091000.jpg. Skipping.
# Warning: Image not found: /content/Images/00078320.jpg. Skipping.
# Warning: Image not found: /content/Images/00080697.jpg. Skipping.
# Copied image 00004572.jpg to yolo_dataset/images/valid/00004572.jpg. Exists: True
# Wrote label 00004572.txt to yolo_dataset/labels/valid/00004572.txt. Exists: True
# Warning: Image not found: /content/Images/00063536.jpg. Skipping.
# Warning: Image not found: /content/Images/00046683.jpg. Skipping.
# Copied image 00004308.jpg to yolo_dataset/images/valid/00004308.jpg. Exists: True
# Wrote label 00004308.txt to yolo_dataset/labels/valid/00004308.txt. Exists: True
# Warning: Image not found: /content/Images/00017705.jpg. Skipping.
# Warning: Image not found: /content/Images/00096832.jpg. Skipping.
# Copied image 00001266.jpg to yolo_dataset/images/valid/00001266.jpg. Exists: True
# Wrote label 00001266.txt to yolo_dataset/labels/valid/00001266.txt. Exists: True
# Warning: Image not found: /content/Images/00093095.jpg. Skipping.
# Warning: Image not found: /content/Images/00097566.jpg. Skipping.
# Warning: Image not found: /content/Images/00037226.jpg. Skipping.
# Warning: Image not found: /content/Images/00067859.jpg. Skipping.
# Warning: Image not found: /content/Images/00089084.jpg. Skipping.
# Warning: Image not found: /content/Images/00095810.jpg. Skipping.
# Warning: Image not found: /content/Images/00047578.jpg. Skipping.
# Warning: Image not found: /content/Images/00008889.jpg. Skipping.
# Warning: Image not found: /content/Images/00087883.jpg. Skipping.
# Warning: Image not found: /content/Images/00027876.jpg. Skipping.
# Warning: Image not found: /content/Images/00035108.jpg. Skipping.
# Warning: Image not found: /content/Images/00031524.jpg. Skipping.
# Warning: Image not found: /content/Images/00023152.jpg. Skipping.
# Warning: Image not found: /content/Images/00091823.jpg. Skipping.
# Warning: Image not found: /content/Images/00030985.jpg. Skipping.
# Warning: Image not found: /content/Images/00040147.jpg. Skipping.
# Warning: Image not found: /content/Images/00025831.jpg. Skipping.
# Warning: Image not found: /content/Images/00077075.jpg. Skipping.
# Warning: Image not found: /content/Images/00011108.jpg. Skipping.
# Warning: Image not found: /content/Images/00029730.jpg. Skipping.
# Warning: Image not found: /content/Images/00009796.jpg. Skipping.
# Warning: Image not found: /content/Images/00045638.jpg. Skipping.
# Warning: Image not found: /content/Images/00017265.jpg. Skipping.
# Warning: Image not found: /content/Images/00100316.jpg. Skipping.
# Warning: Image not found: /content/Images/00019611.jpg. Skipping.
# Warning: Image not found: /content/Images/00024294.jpg. Skipping.
# Warning: Image not found: /content/Images/00105176.jpg. Skipping.
# Warning: Image not found: /content/Images/00049264.jpg. Skipping.
# Warning: Image not found: /content/Images/00053505.jpg. Skipping.
# Warning: Image not found: /content/Images/00013323.jpg. Skipping.
# Warning: Image not found: /content/Images/00087964.jpg. Skipping.
# Warning: Image not found: /content/Images/00105834.jpg. Skipping.
# Warning: Image not found: /content/Images/00031812.jpg. Skipping.
# Warning: Image not found: /content/Images/00108027.jpg. Skipping.
# Warning: Image not found: /content/Images/00071875.jpg. Skipping.
# Warning: Image not found: /content/Images/00076641.jpg. Skipping.
# Warning: Image not found: /content/Images/00048093.jpg. Skipping.
# Warning: Image not found: /content/Images/00092677.jpg. Skipping.
# Copied image 00000990.jpg to yolo_dataset/images/valid/00000990.jpg. Exists: True
# Wrote label 00000990.txt to yolo_dataset/labels/valid/00000990.txt. Exists: True
# Warning: Image not found: /content/Images/00079970.jpg. Skipping.
# Warning: Image not found: /content/Images/00062401.jpg. Skipping.
# Warning: Image not found: /content/Images/00108423.jpg. Skipping.
# Warning: Image not found: /content/Images/00038637.jpg. Skipping.
# Warning: Image not found: /content/Images/00042797.jpg. Skipping.
# Warning: Image not found: /content/Images/00083583.jpg. Skipping.
# Warning: Image not found: /content/Images/00076447.jpg. Skipping.
# Warning: Image not found: /content/Images/00015631.jpg. Skipping.
# Warning: Image not found: /content/Images/00110527.jpg. Skipping.
# Warning: Image not found: /content/Images/00064787.jpg. Skipping.
# Warning: Image not found: /content/Images/00055619.jpg. Skipping.
# Warning: Image not found: /content/Images/00040243.jpg. Skipping.
# Warning: Image not found: /content/Images/00060989.jpg. Skipping.
# Warning: Image not found: /content/Images/00053693.jpg. Skipping.
# Warning: Image not found: /content/Images/00103386.jpg. Skipping.
# Warning: Image not found: /content/Images/00006242.jpg. Skipping.
# Warning: Image not found: /content/Images/00034376.jpg. Skipping.
# Copied image 00004603.jpg to yolo_dataset/images/valid/00004603.jpg. Exists: True
# Wrote label 00004603.txt to yolo_dataset/labels/valid/00004603.txt. Exists: True
# Warning: Image not found: /content/Images/00066605.jpg. Skipping.
# Warning: Image not found: /content/Images/00109709.jpg. Skipping.
# Warning: Image not found: /content/Images/00099167.jpg. Skipping.
# Warning: Image not found: /content/Images/00045038.jpg. Skipping.
# Warning: Image not found: /content/Images/00072216.jpg. Skipping.
# Warning: Image not found: /content/Images/00097167.jpg. Skipping.
# Warning: Image not found: /content/Images/00061241.jpg. Skipping.
# Warning: Image not found: /content/Images/00053133.jpg. Skipping.
# Warning: Image not found: /content/Images/00014341.jpg. Skipping.
# Warning: Image not found: /content/Images/00099129.jpg. Skipping.
# Warning: Image not found: /content/Images/00083257.jpg. Skipping.
# Warning: Image not found: /content/Images/00074913.jpg. Skipping.
# Warning: Image not found: /content/Images/00010084.jpg. Skipping.
# Warning: Image not found: /content/Images/00054135.jpg. Skipping.
# Warning: Image not found: /content/Images/00100754.jpg. Skipping.
# Warning: Image not found: /content/Images/00096760.jpg. Skipping.
# Warning: Image not found: /content/Images/00027650.jpg. Skipping.
# Warning: Image not found: /content/Images/00018539.jpg. Skipping.
# Warning: Image not found: /content/Images/00104778.jpg. Skipping.
# Warning: Image not found: /content/Images/00067020.jpg. Skipping.
# Warning: Image not found: /content/Images/00068134.jpg. Skipping.
# Warning: Image not found: /content/Images/00045725.jpg. Skipping.
# Warning: Image not found: /content/Images/00095282.jpg. Skipping.
# Warning: Image not found: /content/Images/00099257.jpg. Skipping.
# Warning: Image not found: /content/Images/00038674.jpg. Skipping.
# Warning: Image not found: /content/Images/00078624.jpg. Skipping.
# Warning: Image not found: /content/Images/00088213.jpg. Skipping.
# Warning: Image not found: /content/Images/00034374.jpg. Skipping.
# Warning: Image not found: /content/Images/00009848.jpg. Skipping.
# Warning: Image not found: /content/Images/00047591.jpg. Skipping.
# Warning: Image not found: /content/Images/00044324.jpg. Skipping.
# Warning: Image not found: /content/Images/00073507.jpg. Skipping.
# Warning: Image not found: /content/Images/00041342.jpg. Skipping.
# Copied image 00001892.jpg to yolo_dataset/images/valid/00001892.jpg. Exists: True
# Wrote label 00001892.txt to yolo_dataset/labels/valid/00001892.txt. Exists: True
# Warning: Image not found: /content/Images/00043559.jpg. Skipping.
# Warning: Image not found: /content/Images/00067892.jpg. Skipping.
# Warning: Image not found: /content/Images/00056298.jpg. Skipping.
# Warning: Image not found: /content/Images/00024976.jpg. Skipping.
# Warning: Image not found: /content/Images/00104529.jpg. Skipping.
# Warning: Image not found: /content/Images/00008712.jpg. Skipping.
# Warning: Image not found: /content/Images/00023774.jpg. Skipping.
# Warning: Image not found: /content/Images/00025406.jpg. Skipping.
# Warning: Image not found: /content/Images/00078728.jpg. Skipping.
# Warning: Image not found: /content/Images/00072496.jpg. Skipping.
# Warning: Image not found: /content/Images/00049173.jpg. Skipping.
# Warning: Image not found: /content/Images/00058260.jpg. Skipping.
# Warning: Image not found: /content/Images/00034148.jpg. Skipping.
# Warning: Image not found: /content/Images/00076456.jpg. Skipping.
# Warning: Image not found: /content/Images/00015922.jpg. Skipping.
# Warning: Image not found: /content/Images/00103988.jpg. Skipping.
# Warning: Image not found: /content/Images/00025959.jpg. Skipping.
# Warning: Image not found: /content/Images/00110576.jpg. Skipping.
# Warning: Image not found: /content/Images/00020252.jpg. Skipping.
# Warning: Image not found: /content/Images/00023876.jpg. Skipping.
# Warning: Image not found: /content/Images/00050499.jpg. Skipping.
# Warning: Image not found: /content/Images/00023128.jpg. Skipping.
# Warning: Image not found: /content/Images/00090056.jpg. Skipping.
# Warning: Image not found: /content/Images/00034474.jpg. Skipping.
# Warning: Image not found: /content/Images/00089845.jpg. Skipping.
# Warning: Image not found: /content/Images/00087191.jpg. Skipping.
# Warning: Image not found: /content/Images/00029889.jpg. Skipping.
# Warning: Image not found: /content/Images/00012647.jpg. Skipping.
# Warning: Image not found: /content/Images/00025809.jpg. Skipping.
# Warning: Image not found: /content/Images/00022369.jpg. Skipping.
# Warning: Image not found: /content/Images/00093651.jpg. Skipping.
# Warning: Image not found: /content/Images/00086190.jpg. Skipping.
# Warning: Image not found: /content/Images/00035836.jpg. Skipping.
# Warning: Image not found: /content/Images/00082443.jpg. Skipping.
# Warning: Image not found: /content/Images/00080449.jpg. Skipping.
# Copied image 00005302.jpg to yolo_dataset/images/valid/00005302.jpg. Exists: True
# Wrote label 00005302.txt to yolo_dataset/labels/valid/00005302.txt. Exists: True
# Warning: Image not found: /content/Images/00034110.jpg. Skipping.
# Warning: Image not found: /content/Images/00101461.jpg. Skipping.
# Warning: Image not found: /content/Images/00066322.jpg. Skipping.
# Warning: Image not found: /content/Images/00080303.jpg. Skipping.
# Warning: Image not found: /content/Images/00060874.jpg. Skipping.
# Copied image 00001066.jpg to yolo_dataset/images/valid/00001066.jpg. Exists: True
# Wrote label 00001066.txt to yolo_dataset/labels/valid/00001066.txt. Exists: True
# Warning: Image not found: /content/Images/00069809.jpg. Skipping.
# Warning: Image not found: /content/Images/00033786.jpg. Skipping.
# Warning: Image not found: /content/Images/00059993.jpg. Skipping.
# Warning: Image not found: /content/Images/00026111.jpg. Skipping.
# Warning: Image not found: /content/Images/00088545.jpg. Skipping.
# Warning: Image not found: /content/Images/00100771.jpg. Skipping.
# Warning: Image not found: /content/Images/00015554.jpg. Skipping.
# Warning: Image not found: /content/Images/00009227.jpg. Skipping.
# Warning: Image not found: /content/Images/00031818.jpg. Skipping.
# Warning: Image not found: /content/Images/00055478.jpg. Skipping.
# Warning: Image not found: /content/Images/00082662.jpg. Skipping.
# Warning: Image not found: /content/Images/00015583.jpg. Skipping.
# Warning: Image not found: /content/Images/00060924.jpg. Skipping.
# Warning: Image not found: /content/Images/00081441.jpg. Skipping.
# Warning: Image not found: /content/Images/00076805.jpg. Skipping.
# Copied image 00005207.jpg to yolo_dataset/images/valid/00005207.jpg. Exists: True
# Wrote label 00005207.txt to yolo_dataset/labels/valid/00005207.txt. Exists: True
# Warning: Image not found: /content/Images/00010419.jpg. Skipping.
# Warning: Image not found: /content/Images/00050213.jpg. Skipping.
# Warning: Image not found: /content/Images/00078767.jpg. Skipping.
# Warning: Image not found: /content/Images/00093974.jpg. Skipping.
# Warning: Image not found: /content/Images/00024217.jpg. Skipping.
# Copied image 00002972.jpg to yolo_dataset/images/valid/00002972.jpg. Exists: True
# Wrote label 00002972.txt to yolo_dataset/labels/valid/00002972.txt. Exists: True
# Copied image 00001992.jpg to yolo_dataset/images/valid/00001992.jpg. Exists: True
# Wrote label 00001992.txt to yolo_dataset/labels/valid/00001992.txt. Exists: True
# Warning: Image not found: /content/Images/00052033.jpg. Skipping.
# Warning: Image not found: /content/Images/00066631.jpg. Skipping.
# Warning: Image not found: /content/Images/00016554.jpg. Skipping.
# Warning: Image not found: /content/Images/00079736.jpg. Skipping.
# Warning: Image not found: /content/Images/00092085.jpg. Skipping.
# Warning: Image not found: /content/Images/00066947.jpg. Skipping.
# Warning: Image not found: /content/Images/00069774.jpg. Skipping.
# Warning: Image not found: /content/Images/00040398.jpg. Skipping.
# Warning: Image not found: /content/Images/00054077.jpg. Skipping.
# Copied image 00000190.jpg to yolo_dataset/images/valid/00000190.jpg. Exists: True
# Wrote label 00000190.txt to yolo_dataset/labels/valid/00000190.txt. Exists: True
# Warning: Image not found: /content/Images/00095473.jpg. Skipping.
# Warning: Image not found: /content/Images/00055004.jpg. Skipping.
# Warning: Image not found: /content/Images/00062456.jpg. Skipping.
# Warning: Image not found: /content/Images/00006265.jpg. Skipping.
# Warning: Image not found: /content/Images/00011866.jpg. Skipping.
# Warning: Image not found: /content/Images/00077005.jpg. Skipping.
# Warning: Image not found: /content/Images/00036116.jpg. Skipping.
# Warning: Image not found: /content/Images/00010446.jpg. Skipping.
# Copied image 00004548.jpg to yolo_dataset/images/valid/00004548.jpg. Exists: True
# Wrote label 00004548.txt to yolo_dataset/labels/valid/00004548.txt. Exists: True
# Warning: Image not found: /content/Images/00108839.jpg. Skipping.
# Warning: Image not found: /content/Images/00066448.jpg. Skipping.
# Warning: Image not found: /content/Images/00062943.jpg. Skipping.
# Warning: Image not found: /content/Images/00018521.jpg. Skipping.
# Warning: Image not found: /content/Images/00078648.jpg. Skipping.
# Warning: Image not found: /content/Images/00096503.jpg. Skipping.
# Warning: Image not found: /content/Images/00023255.jpg. Skipping.
# Warning: Image not found: /content/Images/00075279.jpg. Skipping.
# Warning: Image not found: /content/Images/00066232.jpg. Skipping.
# Warning: Image not found: /content/Images/00058359.jpg. Skipping.
# Warning: Image not found: /content/Images/00064714.jpg. Skipping.
# Warning: Image not found: /content/Images/00083605.jpg. Skipping.
# Warning: Image not found: /content/Images/00077031.jpg. Skipping.
# Warning: Image not found: /content/Images/00072868.jpg. Skipping.
# Warning: Image not found: /content/Images/00084515.jpg. Skipping.
# Warning: Image not found: /content/Images/00060623.jpg. Skipping.
# Warning: Image not found: /content/Images/00060572.jpg. Skipping.
# Warning: Image not found: /content/Images/00052392.jpg. Skipping.
# Warning: Image not found: /content/Images/00045245.jpg. Skipping.
# Warning: Image not found: /content/Images/00064621.jpg. Skipping.
# Warning: Image not found: /content/Images/00082258.jpg. Skipping.
# Warning: Image not found: /content/Images/00035434.jpg. Skipping.
# Warning: Image not found: /content/Images/00068124.jpg. Skipping.
# Warning: Image not found: /content/Images/00107000.jpg. Skipping.
# Warning: Image not found: /content/Images/00035687.jpg. Skipping.
# Warning: Image not found: /content/Images/00038999.jpg. Skipping.
# Warning: Image not found: /content/Images/00040191.jpg. Skipping.
# Warning: Image not found: /content/Images/00085699.jpg. Skipping.
# Warning: Image not found: /content/Images/00036228.jpg. Skipping.
# Warning: Image not found: /content/Images/00077081.jpg. Skipping.
# Warning: Image not found: /content/Images/00025961.jpg. Skipping.
# Warning: Image not found: /content/Images/00062668.jpg. Skipping.
# Warning: Image not found: /content/Images/00055736.jpg. Skipping.
# Warning: Image not found: /content/Images/00006765.jpg. Skipping.
# Warning: Image not found: /content/Images/00097695.jpg. Skipping.
# Warning: Image not found: /content/Images/00077538.jpg. Skipping.
# Warning: Image not found: /content/Images/00052587.jpg. Skipping.
# Warning: Image not found: /content/Images/00088509.jpg. Skipping.
# Warning: Image not found: /content/Images/00042684.jpg. Skipping.
# Warning: Image not found: /content/Images/00105985.jpg. Skipping.
# Warning: Image not found: /content/Images/00016878.jpg. Skipping.
# Warning: Image not found: /content/Images/00084643.jpg. Skipping.
# Warning: Image not found: /content/Images/00012541.jpg. Skipping.
# Warning: Image not found: /content/Images/00091795.jpg. Skipping.
# Warning: Image not found: /content/Images/00043811.jpg. Skipping.
# Warning: Image not found: /content/Images/00036914.jpg. Skipping.
# Warning: Image not found: /content/Images/00086475.jpg. Skipping.
# Warning: Image not found: /content/Images/00021901.jpg. Skipping.
# Warning: Image not found: /content/Images/00047969.jpg. Skipping.
# Warning: Image not found: /content/Images/00015273.jpg. Skipping.
# Warning: Image not found: /content/Images/00008113.jpg. Skipping.
# Copied image 00000061.jpg to yolo_dataset/images/valid/00000061.jpg. Exists: True
# Wrote label 00000061.txt to yolo_dataset/labels/valid/00000061.txt. Exists: True
# Warning: Image not found: /content/Images/00046456.jpg. Skipping.
# Warning: Image not found: /content/Images/00068104.jpg. Skipping.
# Warning: Image not found: /content/Images/00018349.jpg. Skipping.
# Warning: Image not found: /content/Images/00102133.jpg. Skipping.
# Warning: Image not found: /content/Images/00091138.jpg. Skipping.
# Warning: Image not found: /content/Images/00051333.jpg. Skipping.
# Warning: Image not found: /content/Images/00043155.jpg. Skipping.
# Warning: Image not found: /content/Images/00089013.jpg. Skipping.
# Warning: Image not found: /content/Images/00018393.jpg. Skipping.
# Warning: Image not found: /content/Images/00080111.jpg. Skipping.
# Warning: Image not found: /content/Images/00057847.jpg. Skipping.
# Warning: Image not found: /content/Images/00041158.jpg. Skipping.
# Warning: Image not found: /content/Images/00011394.jpg. Skipping.
# Warning: Image not found: /content/Images/00027737.jpg. Skipping.
# Warning: Image not found: /content/Images/00066544.jpg. Skipping.
# Warning: Image not found: /content/Images/00051619.jpg. Skipping.
# Warning: Image not found: /content/Images/00033289.jpg. Skipping.
# Warning: Image not found: /content/Images/00015050.jpg. Skipping.
# Warning: Image not found: /content/Images/00048846.jpg. Skipping.
# Warning: Image not found: /content/Images/00013426.jpg. Skipping.
# Warning: Image not found: /content/Images/00105203.jpg. Skipping.
# Warning: Image not found: /content/Images/00080238.jpg. Skipping.
# Warning: Image not found: /content/Images/00075215.jpg. Skipping.
# Warning: Image not found: /content/Images/00104492.jpg. Skipping.
# Warning: Image not found: /content/Images/00093858.jpg. Skipping.
# Warning: Image not found: /content/Images/00016007.jpg. Skipping.
# Warning: Image not found: /content/Images/00022386.jpg. Skipping.
# Warning: Image not found: /content/Images/00085011.jpg. Skipping.
# Warning: Image not found: /content/Images/00105250.jpg. Skipping.
# Warning: Image not found: /content/Images/00093650.jpg. Skipping.
# Warning: Image not found: /content/Images/00017938.jpg. Skipping.
# Copied image 00000835.jpg to yolo_dataset/images/valid/00000835.jpg. Exists: True
# Wrote label 00000835.txt to yolo_dataset/labels/valid/00000835.txt. Exists: True
# Warning: Image not found: /content/Images/00105562.jpg. Skipping.
# Warning: Image not found: /content/Images/00056806.jpg. Skipping.
# Warning: Image not found: /content/Images/00083566.jpg. Skipping.
# Warning: Image not found: /content/Images/00095312.jpg. Skipping.
# Warning: Image not found: /content/Images/00047672.jpg. Skipping.
# Copied image 00000947.jpg to yolo_dataset/images/valid/00000947.jpg. Exists: True
# Wrote label 00000947.txt to yolo_dataset/labels/valid/00000947.txt. Exists: True
# Warning: Image not found: /content/Images/00013198.jpg. Skipping.
# Warning: Image not found: /content/Images/00034431.jpg. Skipping.
# Warning: Image not found: /content/Images/00068339.jpg. Skipping.
# Warning: Image not found: /content/Images/00095548.jpg. Skipping.
# Warning: Image not found: /content/Images/00065971.jpg. Skipping.
# Warning: Image not found: /content/Images/00029803.jpg. Skipping.
# Warning: Image not found: /content/Images/00034534.jpg. Skipping.
# Warning: Image not found: /content/Images/00031190.jpg. Skipping.
# Warning: Image not found: /content/Images/00102879.jpg. Skipping.
# Warning: Image not found: /content/Images/00044722.jpg. Skipping.
# Warning: Image not found: /content/Images/00082396.jpg. Skipping.
# Warning: Image not found: /content/Images/00040558.jpg. Skipping.
# Warning: Image not found: /content/Images/00067703.jpg. Skipping.
# Warning: Image not found: /content/Images/00014541.jpg. Skipping.
# Warning: Image not found: /content/Images/00103069.jpg. Skipping.
# Warning: Image not found: /content/Images/00101330.jpg. Skipping.
# Warning: Image not found: /content/Images/00064959.jpg. Skipping.
# Warning: Image not found: /content/Images/00048229.jpg. Skipping.
# Warning: Image not found: /content/Images/00047524.jpg. Skipping.
# Warning: Image not found: /content/Images/00011314.jpg. Skipping.
# Warning: Image not found: /content/Images/00032641.jpg. Skipping.
# Warning: Image not found: /content/Images/00090539.jpg. Skipping.
# Warning: Image not found: /content/Images/00086922.jpg. Skipping.
# Warning: Image not found: /content/Images/00091632.jpg. Skipping.
# Warning: Image not found: /content/Images/00038087.jpg. Skipping.
# Warning: Image not found: /content/Images/00020590.jpg. Skipping.
# Warning: Image not found: /content/Images/00061740.jpg. Skipping.
# Warning: Image not found: /content/Images/00080287.jpg. Skipping.
# Warning: Image not found: /content/Images/00010150.jpg. Skipping.
# Warning: Image not found: /content/Images/00061172.jpg. Skipping.
# Warning: Image not found: /content/Images/00038681.jpg. Skipping.
# Warning: Image not found: /content/Images/00079470.jpg. Skipping.
# Warning: Image not found: /content/Images/00049704.jpg. Skipping.
# Copied image 00000424.jpg to yolo_dataset/images/valid/00000424.jpg. Exists: True
# Wrote label 00000424.txt to yolo_dataset/labels/valid/00000424.txt. Exists: True
# Warning: Image not found: /content/Images/00077597.jpg. Skipping.
# Warning: Image not found: /content/Images/00051091.jpg. Skipping.
# Warning: Image not found: /content/Images/00057603.jpg. Skipping.
# Copied image 00005579.jpg to yolo_dataset/images/valid/00005579.jpg. Exists: True
# Wrote label 00005579.txt to yolo_dataset/labels/valid/00005579.txt. Exists: True
# Warning: Image not found: /content/Images/00043765.jpg. Skipping.
# Warning: Image not found: /content/Images/00088917.jpg. Skipping.
# Copied image 00003931.jpg to yolo_dataset/images/valid/00003931.jpg. Exists: True
# Wrote label 00003931.txt to yolo_dataset/labels/valid/00003931.txt. Exists: True
# Warning: Image not found: /content/Images/00023977.jpg. Skipping.
# Warning: Image not found: /content/Images/00038255.jpg. Skipping.
# Warning: Image not found: /content/Images/00033188.jpg. Skipping.
# Warning: Image not found: /content/Images/00026571.jpg. Skipping.
# Warning: Image not found: /content/Images/00066750.jpg. Skipping.
# Copied image 00002819.jpg to yolo_dataset/images/valid/00002819.jpg. Exists: True
# Wrote label 00002819.txt to yolo_dataset/labels/valid/00002819.txt. Exists: True
# Warning: Image not found: /content/Images/00079723.jpg. Skipping.
# Warning: Image not found: /content/Images/00063328.jpg. Skipping.
# Warning: Image not found: /content/Images/00075848.jpg. Skipping.
# Warning: Image not found: /content/Images/00027514.jpg. Skipping.
# Warning: Image not found: /content/Images/00036352.jpg. Skipping.
# Warning: Image not found: /content/Images/00068477.jpg. Skipping.
# Warning: Image not found: /content/Images/00083539.jpg. Skipping.
# Warning: Image not found: /content/Images/00065002.jpg. Skipping.
# Warning: Image not found: /content/Images/00018052.jpg. Skipping.
# Warning: Image not found: /content/Images/00048863.jpg. Skipping.
# Warning: Image not found: /content/Images/00009892.jpg. Skipping.
# Warning: Image not found: /content/Images/00073708.jpg. Skipping.
# Warning: Image not found: /content/Images/00066193.jpg. Skipping.
# Warning: Image not found: /content/Images/00038234.jpg. Skipping.
# Warning: Image not found: /content/Images/00065020.jpg. Skipping.
# Warning: Image not found: /content/Images/00021264.jpg. Skipping.
# Warning: Image not found: /content/Images/00104417.jpg. Skipping.
# Warning: Image not found: /content/Images/00047603.jpg. Skipping.
# Warning: Image not found: /content/Images/00102030.jpg. Skipping.
# Warning: Image not found: /content/Images/00031917.jpg. Skipping.
# Warning: Image not found: /content/Images/00029350.jpg. Skipping.
# Warning: Image not found: /content/Images/00017156.jpg. Skipping.
# Warning: Image not found: /content/Images/00054540.jpg. Skipping.
# Warning: Image not found: /content/Images/00017042.jpg. Skipping.
# Warning: Image not found: /content/Images/00089023.jpg. Skipping.
# Warning: Image not found: /content/Images/00042084.jpg. Skipping.
# Warning: Image not found: /content/Images/00074543.jpg. Skipping.
# Warning: Image not found: /content/Images/00051923.jpg. Skipping.
# Warning: Image not found: /content/Images/00033292.jpg. Skipping.
# Warning: Image not found: /content/Images/00028682.jpg. Skipping.
# Warning: Image not found: /content/Images/00023402.jpg. Skipping.
# Warning: Image not found: /content/Images/00058600.jpg. Skipping.
# Warning: Image not found: /content/Images/00034462.jpg. Skipping.
# Warning: Image not found: /content/Images/00022121.jpg. Skipping.
# Warning: Image not found: /content/Images/00092118.jpg. Skipping.
# Warning: Image not found: /content/Images/00034564.jpg. Skipping.
# Warning: Image not found: /content/Images/00076644.jpg. Skipping.
# Warning: Image not found: /content/Images/00041588.jpg. Skipping.
# Warning: Image not found: /content/Images/00020531.jpg. Skipping.
# Warning: Image not found: /content/Images/00063268.jpg. Skipping.
# Warning: Image not found: /content/Images/00027928.jpg. Skipping.
# Warning: Image not found: /content/Images/00065569.jpg. Skipping.
# Warning: Image not found: /content/Images/00011677.jpg. Skipping.
# Warning: Image not found: /content/Images/00031128.jpg. Skipping.
# Warning: Image not found: /content/Images/00097208.jpg. Skipping.
# Warning: Image not found: /content/Images/00038850.jpg. Skipping.
# Warning: Image not found: /content/Images/00047733.jpg. Skipping.
# Warning: Image not found: /content/Images/00031235.jpg. Skipping.
# Warning: Image not found: /content/Images/00012247.jpg. Skipping.
# Warning: Image not found: /content/Images/00072668.jpg. Skipping.
# Warning: Image not found: /content/Images/00018491.jpg. Skipping.
# Warning: Image not found: /content/Images/00084892.jpg. Skipping.
# Warning: Image not found: /content/Images/00052797.jpg. Skipping.
# Warning: Image not found: /content/Images/00006384.jpg. Skipping.
# Warning: Image not found: /content/Images/00075760.jpg. Skipping.
# Warning: Image not found: /content/Images/00081805.jpg. Skipping.
# Warning: Image not found: /content/Images/00078679.jpg. Skipping.
# Warning: Image not found: /content/Images/00064343.jpg. Skipping.
# Warning: Image not found: /content/Images/00009947.jpg. Skipping.
# Warning: Image not found: /content/Images/00109005.jpg. Skipping.
# Warning: Image not found: /content/Images/00060281.jpg. Skipping.
# Warning: Image not found: /content/Images/00090385.jpg. Skipping.
# Warning: Image not found: /content/Images/00088963.jpg. Skipping.
# Warning: Image not found: /content/Images/00026003.jpg. Skipping.
# Warning: Image not found: /content/Images/00101792.jpg. Skipping.
# Warning: Image not found: /content/Images/00054242.jpg. Skipping.
# Warning: Image not found: /content/Images/00084576.jpg. Skipping.
# Warning: Image not found: /content/Images/00089541.jpg. Skipping.
# Warning: Image not found: /content/Images/00083564.jpg. Skipping.
# Warning: Image not found: /content/Images/00089669.jpg. Skipping.
# Warning: Image not found: /content/Images/00070309.jpg. Skipping.
# Warning: Image not found: /content/Images/00101948.jpg. Skipping.
# Warning: Image not found: /content/Images/00009936.jpg. Skipping.
# Warning: Image not found: /content/Images/00088513.jpg. Skipping.
# Warning: Image not found: /content/Images/00044247.jpg. Skipping.
# Warning: Image not found: /content/Images/00063435.jpg. Skipping.
# Warning: Image not found: /content/Images/00066705.jpg. Skipping.
# Warning: Image not found: /content/Images/00057437.jpg. Skipping.
# Warning: Image not found: /content/Images/00039368.jpg. Skipping.
# Warning: Image not found: /content/Images/00010759.jpg. Skipping.
# Warning: Image not found: /content/Images/00068844.jpg. Skipping.
# Warning: Image not found: /content/Images/00098601.jpg. Skipping.
# Warning: Image not found: /content/Images/00052810.jpg. Skipping.
# Warning: Image not found: /content/Images/00031683.jpg. Skipping.
# Warning: Image not found: /content/Images/00037773.jpg. Skipping.
# Warning: Image not found: /content/Images/00098300.jpg. Skipping.
# Warning: Image not found: /content/Images/00055798.jpg. Skipping.
# Warning: Image not found: /content/Images/00045559.jpg. Skipping.
# Warning: Image not found: /content/Images/00024147.jpg. Skipping.
# Warning: Image not found: /content/Images/00006788.jpg. Skipping.
# Warning: Image not found: /content/Images/00084723.jpg. Skipping.
# Warning: Image not found: /content/Images/00022316.jpg. Skipping.
# Warning: Image not found: /content/Images/00100256.jpg. Skipping.
# Warning: Image not found: /content/Images/00082193.jpg. Skipping.
# Warning: Image not found: /content/Images/00080006.jpg. Skipping.
# Warning: Image not found: /content/Images/00007800.jpg. Skipping.
# Warning: Image not found: /content/Images/00020271.jpg. Skipping.
# Warning: Image not found: /content/Images/00007932.jpg. Skipping.
# Warning: Image not found: /content/Images/00034973.jpg. Skipping.
# Warning: Image not found: /content/Images/00009851.jpg. Skipping.
# Warning: Image not found: /content/Images/00060385.jpg. Skipping.
# Warning: Image not found: /content/Images/00110241.jpg. Skipping.
# Warning: Image not found: /content/Images/00036203.jpg. Skipping.
# Warning: Image not found: /content/Images/00067977.jpg. Skipping.
# Copied image 00000070.jpg to yolo_dataset/images/valid/00000070.jpg. Exists: True
# Wrote label 00000070.txt to yolo_dataset/labels/valid/00000070.txt. Exists: True
# Warning: Image not found: /content/Images/00024101.jpg. Skipping.
# Warning: Image not found: /content/Images/00079680.jpg. Skipping.
# Warning: Image not found: /content/Images/00007156.jpg. Skipping.
# Warning: Image not found: /content/Images/00089454.jpg. Skipping.
# Warning: Image not found: /content/Images/00074038.jpg. Skipping.
# Warning: Image not found: /content/Images/00050530.jpg. Skipping.
# Warning: Image not found: /content/Images/00008274.jpg. Skipping.
# Warning: Image not found: /content/Images/00012186.jpg. Skipping.
# Warning: Image not found: /content/Images/00016128.jpg. Skipping.
# Warning: Image not found: /content/Images/00041901.jpg. Skipping.
# Copied image 00001363.jpg to yolo_dataset/images/valid/00001363.jpg. Exists: True
# Wrote label 00001363.txt to yolo_dataset/labels/valid/00001363.txt. Exists: True
# Warning: Image not found: /content/Images/00025275.jpg. Skipping.
# Warning: Image not found: /content/Images/00080555.jpg. Skipping.
# Warning: Image not found: /content/Images/00094503.jpg. Skipping.
# Warning: Image not found: /content/Images/00065476.jpg. Skipping.
# Warning: Image not found: /content/Images/00092492.jpg. Skipping.
# Warning: Image not found: /content/Images/00031711.jpg. Skipping.
# Warning: Image not found: /content/Images/00068343.jpg. Skipping.
# Warning: Image not found: /content/Images/00053744.jpg. Skipping.
# Warning: Image not found: /content/Images/00006337.jpg. Skipping.
# Warning: Image not found: /content/Images/00025179.jpg. Skipping.
# Warning: Image not found: /content/Images/00095635.jpg. Skipping.
# Warning: Image not found: /content/Images/00097463.jpg. Skipping.
# Warning: Image not found: /content/Images/00081353.jpg. Skipping.
# Warning: Image not found: /content/Images/00018990.jpg. Skipping.
# Warning: Image not found: /content/Images/00011338.jpg. Skipping.
# Warning: Image not found: /content/Images/00093633.jpg. Skipping.
# Warning: Image not found: /content/Images/00050030.jpg. Skipping.
# Warning: Image not found: /content/Images/00007063.jpg. Skipping.
# Warning: Image not found: /content/Images/00078837.jpg. Skipping.
# Warning: Image not found: /content/Images/00027202.jpg. Skipping.
# Warning: Image not found: /content/Images/00009136.jpg. Skipping.
# Warning: Image not found: /content/Images/00015229.jpg. Skipping.
# Warning: Image not found: /content/Images/00036904.jpg. Skipping.
# Warning: Image not found: /content/Images/00034383.jpg. Skipping.
# Warning: Image not found: /content/Images/00104313.jpg. Skipping.
# Warning: Image not found: /content/Images/00071409.jpg. Skipping.
# Warning: Image not found: /content/Images/00022688.jpg. Skipping.
# Warning: Image not found: /content/Images/00099564.jpg. Skipping.
# Warning: Image not found: /content/Images/00035984.jpg. Skipping.
# Warning: Image not found: /content/Images/00102956.jpg. Skipping.
# Warning: Image not found: /content/Images/00067722.jpg. Skipping.
# Warning: Image not found: /content/Images/00088076.jpg. Skipping.
# Warning: Image not found: /content/Images/00101641.jpg. Skipping.
# Warning: Image not found: /content/Images/00013109.jpg. Skipping.
# Warning: Image not found: /content/Images/00096382.jpg. Skipping.
# Warning: Image not found: /content/Images/00055814.jpg. Skipping.
# Warning: Image not found: /content/Images/00055150.jpg. Skipping.
# Warning: Image not found: /content/Images/00063614.jpg. Skipping.
# Copied image 00002407.jpg to yolo_dataset/images/valid/00002407.jpg. Exists: True
# Wrote label 00002407.txt to yolo_dataset/labels/valid/00002407.txt. Exists: True
# Warning: Image not found: /content/Images/00054374.jpg. Skipping.
# Warning: Image not found: /content/Images/00078249.jpg. Skipping.
# Warning: Image not found: /content/Images/00025828.jpg. Skipping.
# Warning: Image not found: /content/Images/00056101.jpg. Skipping.
# Warning: Image not found: /content/Images/00100988.jpg. Skipping.
# Warning: Image not found: /content/Images/00006031.jpg. Skipping.
# Warning: Image not found: /content/Images/00055200.jpg. Skipping.
# Warning: Image not found: /content/Images/00075272.jpg. Skipping.
# Warning: Image not found: /content/Images/00085935.jpg. Skipping.
# Warning: Image not found: /content/Images/00033523.jpg. Skipping.
# Warning: Image not found: /content/Images/00012344.jpg. Skipping.
# Warning: Image not found: /content/Images/00045982.jpg. Skipping.
# Warning: Image not found: /content/Images/00051164.jpg. Skipping.
# Copied image 00002565.jpg to yolo_dataset/images/valid/00002565.jpg. Exists: True
# Wrote label 00002565.txt to yolo_dataset/labels/valid/00002565.txt. Exists: True
# Warning: Image not found: /content/Images/00021202.jpg. Skipping.
# Warning: Image not found: /content/Images/00079699.jpg. Skipping.
# Warning: Image not found: /content/Images/00015083.jpg. Skipping.
# Copied image 00002795.jpg to yolo_dataset/images/valid/00002795.jpg. Exists: True
# Wrote label 00002795.txt to yolo_dataset/labels/valid/00002795.txt. Exists: True
# Warning: Image not found: /content/Images/00027885.jpg. Skipping.
# Warning: Image not found: /content/Images/00071474.jpg. Skipping.
# Warning: Image not found: /content/Images/00040606.jpg. Skipping.
# Warning: Image not found: /content/Images/00098090.jpg. Skipping.
# Warning: Image not found: /content/Images/00096830.jpg. Skipping.
# Warning: Image not found: /content/Images/00046274.jpg. Skipping.
# Warning: Image not found: /content/Images/00041640.jpg. Skipping.
# Warning: Image not found: /content/Images/00024753.jpg. Skipping.
# Warning: Image not found: /content/Images/00048658.jpg. Skipping.
# Warning: Image not found: /content/Images/00059626.jpg. Skipping.
# Warning: Image not found: /content/Images/00080713.jpg. Skipping.
# Warning: Image not found: /content/Images/00101447.jpg. Skipping.
# Warning: Image not found: /content/Images/00105307.jpg. Skipping.
# Warning: Image not found: /content/Images/00102601.jpg. Skipping.
# Warning: Image not found: /content/Images/00085111.jpg. Skipping.
# Warning: Image not found: /content/Images/00010156.jpg. Skipping.
# Warning: Image not found: /content/Images/00043888.jpg. Skipping.
# Warning: Image not found: /content/Images/00098686.jpg. Skipping.
# Warning: Image not found: /content/Images/00081205.jpg. Skipping.
# Warning: Image not found: /content/Images/00093708.jpg. Skipping.
# Warning: Image not found: /content/Images/00030587.jpg. Skipping.
# Warning: Image not found: /content/Images/00086605.jpg. Skipping.
# Warning: Image not found: /content/Images/00037894.jpg. Skipping.
# Warning: Image not found: /content/Images/00018918.jpg. Skipping.
# Warning: Image not found: /content/Images/00107442.jpg. Skipping.
# Warning: Image not found: /content/Images/00016214.jpg. Skipping.
# Warning: Image not found: /content/Images/00086926.jpg. Skipping.
# Warning: Image not found: /content/Images/00022373.jpg. Skipping.
# Warning: Image not found: /content/Images/00108831.jpg. Skipping.
# Warning: Image not found: /content/Images/00108617.jpg. Skipping.
# Warning: Image not found: /content/Images/00025032.jpg. Skipping.
# Warning: Image not found: /content/Images/00034349.jpg. Skipping.
# Warning: Image not found: /content/Images/00043835.jpg. Skipping.
# Warning: Image not found: /content/Images/00029422.jpg. Skipping.
# Warning: Image not found: /content/Images/00068363.jpg. Skipping.
# Warning: Image not found: /content/Images/00014373.jpg. Skipping.
# Warning: Image not found: /content/Images/00013071.jpg. Skipping.
# Warning: Image not found: /content/Images/00035258.jpg. Skipping.
# Warning: Image not found: /content/Images/00045338.jpg. Skipping.
# Warning: Image not found: /content/Images/00085982.jpg. Skipping.
# Warning: Image not found: /content/Images/00059642.jpg. Skipping.
# Warning: Image not found: /content/Images/00096827.jpg. Skipping.
# Warning: Image not found: /content/Images/00074271.jpg. Skipping.
# Warning: Image not found: /content/Images/00019059.jpg. Skipping.
# Copied image 00002697.jpg to yolo_dataset/images/valid/00002697.jpg. Exists: True
# Wrote label 00002697.txt to yolo_dataset/labels/valid/00002697.txt. Exists: True
# Warning: Image not found: /content/Images/00097798.jpg. Skipping.
# Warning: Image not found: /content/Images/00053595.jpg. Skipping.
# Warning: Image not found: /content/Images/00016717.jpg. Skipping.
# Warning: Image not found: /content/Images/00060373.jpg. Skipping.
# Warning: Image not found: /content/Images/00093562.jpg. Skipping.
# Warning: Image not found: /content/Images/00081488.jpg. Skipping.
# Warning: Image not found: /content/Images/00045261.jpg. Skipping.
# Warning: Image not found: /content/Images/00068646.jpg. Skipping.
# Warning: Image not found: /content/Images/00068044.jpg. Skipping.
# Warning: Image not found: /content/Images/00035176.jpg. Skipping.
# Warning: Image not found: /content/Images/00040354.jpg. Skipping.
# Warning: Image not found: /content/Images/00067639.jpg. Skipping.
# Warning: Image not found: /content/Images/00054311.jpg. Skipping.
# Warning: Image not found: /content/Images/00088575.jpg. Skipping.
# Warning: Image not found: /content/Images/00096957.jpg. Skipping.
# Warning: Image not found: /content/Images/00031454.jpg. Skipping.
# Warning: Image not found: /content/Images/00047614.jpg. Skipping.
# Warning: Image not found: /content/Images/00016491.jpg. Skipping.
# Warning: Image not found: /content/Images/00034385.jpg. Skipping.
# Warning: Image not found: /content/Images/00008970.jpg. Skipping.
# Warning: Image not found: /content/Images/00030906.jpg. Skipping.
# Warning: Image not found: /content/Images/00077762.jpg. Skipping.
# Warning: Image not found: /content/Images/00108673.jpg. Skipping.
# Warning: Image not found: /content/Images/00088480.jpg. Skipping.
# Warning: Image not found: /content/Images/00101199.jpg. Skipping.
# Warning: Image not found: /content/Images/00019802.jpg. Skipping.
# Warning: Image not found: /content/Images/00035458.jpg. Skipping.
# Warning: Image not found: /content/Images/00046843.jpg. Skipping.
# Warning: Image not found: /content/Images/00096525.jpg. Skipping.
# Warning: Image not found: /content/Images/00015973.jpg. Skipping.
# Warning: Image not found: /content/Images/00030142.jpg. Skipping.
# Warning: Image not found: /content/Images/00078692.jpg. Skipping.
# Warning: Image not found: /content/Images/00032962.jpg. Skipping.
# Warning: Image not found: /content/Images/00032721.jpg. Skipping.
# Copied image 00002393.jpg to yolo_dataset/images/valid/00002393.jpg. Exists: True
# Wrote label 00002393.txt to yolo_dataset/labels/valid/00002393.txt. Exists: True
# Warning: Image not found: /content/Images/00062613.jpg. Skipping.
# Warning: Image not found: /content/Images/00094054.jpg. Skipping.
# Warning: Image not found: /content/Images/00012447.jpg. Skipping.
# Warning: Image not found: /content/Images/00097035.jpg. Skipping.
# Warning: Image not found: /content/Images/00074912.jpg. Skipping.
# Warning: Image not found: /content/Images/00021070.jpg. Skipping.
# Warning: Image not found: /content/Images/00011306.jpg. Skipping.
# Warning: Image not found: /content/Images/00023439.jpg. Skipping.
# Warning: Image not found: /content/Images/00044217.jpg. Skipping.
# Warning: Image not found: /content/Images/00077819.jpg. Skipping.
# Warning: Image not found: /content/Images/00040348.jpg. Skipping.
# Warning: Image not found: /content/Images/00105903.jpg. Skipping.
# Warning: Image not found: /content/Images/00071804.jpg. Skipping.
# Warning: Image not found: /content/Images/00041468.jpg. Skipping.
# Warning: Image not found: /content/Images/00033185.jpg. Skipping.
# Warning: Image not found: /content/Images/00007354.jpg. Skipping.
# Warning: Image not found: /content/Images/00031676.jpg. Skipping.
# Warning: Image not found: /content/Images/00080592.jpg. Skipping.
# Warning: Image not found: /content/Images/00026656.jpg. Skipping.
# Copied image 00000877.jpg to yolo_dataset/images/valid/00000877.jpg. Exists: True
# Wrote label 00000877.txt to yolo_dataset/labels/valid/00000877.txt. Exists: True
# Warning: Image not found: /content/Images/00096146.jpg. Skipping.
# Warning: Image not found: /content/Images/00085182.jpg. Skipping.
# Warning: Image not found: /content/Images/00101453.jpg. Skipping.
# Copied image 00002445.jpg to yolo_dataset/images/valid/00002445.jpg. Exists: True
# Wrote label 00002445.txt to yolo_dataset/labels/valid/00002445.txt. Exists: True
# Warning: Image not found: /content/Images/00042925.jpg. Skipping.
# Warning: Image not found: /content/Images/00035766.jpg. Skipping.
# Warning: Image not found: /content/Images/00105058.jpg. Skipping.
# Warning: Image not found: /content/Images/00012602.jpg. Skipping.
# Warning: Image not found: /content/Images/00045170.jpg. Skipping.
# Warning: Image not found: /content/Images/00060255.jpg. Skipping.
# Warning: Image not found: /content/Images/00093070.jpg. Skipping.
# Warning: Image not found: /content/Images/00070977.jpg. Skipping.
# Warning: Image not found: /content/Images/00087263.jpg. Skipping.
# Warning: Image not found: /content/Images/00053060.jpg. Skipping.
# Warning: Image not found: /content/Images/00079248.jpg. Skipping.
# Warning: Image not found: /content/Images/00106365.jpg. Skipping.
# Warning: Image not found: /content/Images/00084180.jpg. Skipping.
# Warning: Image not found: /content/Images/00042199.jpg. Skipping.
# Warning: Image not found: /content/Images/00067189.jpg. Skipping.
# Warning: Image not found: /content/Images/00024681.jpg. Skipping.
# Warning: Image not found: /content/Images/00075079.jpg. Skipping.
# Warning: Image not found: /content/Images/00073486.jpg. Skipping.
# Warning: Image not found: /content/Images/00012713.jpg. Skipping.
# Warning: Image not found: /content/Images/00082997.jpg. Skipping.
# Warning: Image not found: /content/Images/00028237.jpg. Skipping.
# Warning: Image not found: /content/Images/00066143.jpg. Skipping.
# Warning: Image not found: /content/Images/00104542.jpg. Skipping.
# Warning: Image not found: /content/Images/00096917.jpg. Skipping.
# Warning: Image not found: /content/Images/00046136.jpg. Skipping.
# Warning: Image not found: /content/Images/00006694.jpg. Skipping.
# Copied image 00001980.jpg to yolo_dataset/images/valid/00001980.jpg. Exists: True
# Wrote label 00001980.txt to yolo_dataset/labels/valid/00001980.txt. Exists: True
# Warning: Image not found: /content/Images/00028628.jpg. Skipping.
# Warning: Image not found: /content/Images/00107531.jpg. Skipping.
# Warning: Image not found: /content/Images/00021256.jpg. Skipping.
# Warning: Image not found: /content/Images/00013272.jpg. Skipping.
# Warning: Image not found: /content/Images/00031439.jpg. Skipping.
# Warning: Image not found: /content/Images/00095606.jpg. Skipping.
# Warning: Image not found: /content/Images/00099297.jpg. Skipping.
# Warning: Image not found: /content/Images/00057394.jpg. Skipping.
# Warning: Image not found: /content/Images/00008330.jpg. Skipping.
# Warning: Image not found: /content/Images/00036246.jpg. Skipping.
# Warning: Image not found: /content/Images/00073497.jpg. Skipping.
# Warning: Image not found: /content/Images/00110142.jpg. Skipping.
# Warning: Image not found: /content/Images/00105403.jpg. Skipping.
# Warning: Image not found: /content/Images/00048047.jpg. Skipping.
# Warning: Image not found: /content/Images/00107975.jpg. Skipping.
# Warning: Image not found: /content/Images/00095303.jpg. Skipping.
# Warning: Image not found: /content/Images/00043526.jpg. Skipping.
# Warning: Image not found: /content/Images/00023060.jpg. Skipping.
# Warning: Image not found: /content/Images/00032552.jpg. Skipping.
# Copied image 00002745.jpg to yolo_dataset/images/valid/00002745.jpg. Exists: True
# Wrote label 00002745.txt to yolo_dataset/labels/valid/00002745.txt. Exists: True
# Warning: Image not found: /content/Images/00035239.jpg. Skipping.
# Warning: Image not found: /content/Images/00085198.jpg. Skipping.
# Warning: Image not found: /content/Images/00061690.jpg. Skipping.
# Warning: Image not found: /content/Images/00025461.jpg. Skipping.
# Warning: Image not found: /content/Images/00087817.jpg. Skipping.
# Warning: Image not found: /content/Images/00029383.jpg. Skipping.
# Warning: Image not found: /content/Images/00051103.jpg. Skipping.
# Warning: Image not found: /content/Images/00063578.jpg. Skipping.
# Warning: Image not found: /content/Images/00061476.jpg. Skipping.
# Warning: Image not found: /content/Images/00107101.jpg. Skipping.
# Warning: Image not found: /content/Images/00082697.jpg. Skipping.
# Warning: Image not found: /content/Images/00053822.jpg. Skipping.
# Warning: Image not found: /content/Images/00026490.jpg. Skipping.
# ...
# image 399/558 /content/yolov5/yolo_dataset/images/test/00004032.jpg: 448x640 19 cars, 6.5ms
# image 400/558 /content/yolov5/yolo_dataset/images/test/00004045.jpg: 448x640 2 cars, 6.4ms
# image 401/558 /content/yolov5/yolo_dataset/images/test/00004047.jpg: 448x640 1 car, 6.4ms
# image 402/558 /content/yolov5/yolo_dataset/images/test/00004074.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 403/558 /content/yolov5/yolo_dataset/images/test/00004079.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 404/558 /content/yolov5/yolo_dataset/images/test/00004082.jpg: 448x640 12 cars, 1 articulated_truck, 1 bus, 3 pickup_trucks, 6.4ms
# image 405/558 /content/yolov5/yolo_dataset/images/test/00004102.jpg: 448x640 2 cars, 6.4ms
# image 406/558 /content/yolov5/yolo_dataset/images/test/00004110.jpg: 448x640 1 pickup_truck, 6.4ms
# image 407/558 /content/yolov5/yolo_dataset/images/test/00004120.jpg: 448x640 1 car, 6.4ms
# image 408/558 /content/yolov5/yolo_dataset/images/test/00004130.jpg: 448x640 4 cars, 6.3ms
# image 409/558 /content/yolov5/yolo_dataset/images/test/00004139.jpg: 448x640 10 cars, 1 bus, 1 pickup_truck, 6.9ms
# image 410/558 /content/yolov5/yolo_dataset/images/test/00004141.jpg: 448x640 1 pickup_truck, 6.3ms
# image 411/558 /content/yolov5/yolo_dataset/images/test/00004147.jpg: 448x640 2 cars, 6.3ms
# image 412/558 /content/yolov5/yolo_dataset/images/test/00004151.jpg: 448x640 1 car, 1 bus, 6.3ms
# image 413/558 /content/yolov5/yolo_dataset/images/test/00004152.jpg: 448x640 15 cars, 6.3ms
# image 414/558 /content/yolov5/yolo_dataset/images/test/00004168.jpg: 448x640 (no detections), 6.4ms
# image 415/558 /content/yolov5/yolo_dataset/images/test/00004171.jpg: 448x640 7 cars, 1 bus, 1 pickup_truck, 6.4ms
# image 416/558 /content/yolov5/yolo_dataset/images/test/00004177.jpg: 448x640 1 car, 6.4ms
# image 417/558 /content/yolov5/yolo_dataset/images/test/00004180.jpg: 448x640 2 cars, 1 bus, 1 pickup_truck, 6.3ms
# image 418/558 /content/yolov5/yolo_dataset/images/test/00004207.jpg: 448x640 6 cars, 6.3ms
# image 419/558 /content/yolov5/yolo_dataset/images/test/00004218.jpg: 448x640 2 cars, 6.4ms
# image 420/558 /content/yolov5/yolo_dataset/images/test/00004222.jpg: 448x640 (no detections), 6.5ms
# image 421/558 /content/yolov5/yolo_dataset/images/test/00004244.jpg: 448x640 2 cars, 6.3ms
# image 422/558 /content/yolov5/yolo_dataset/images/test/00004255.jpg: 448x640 1 car, 1 bus, 6.4ms
# image 423/558 /content/yolov5/yolo_dataset/images/test/00004269.jpg: 448x640 2 cars, 1 pickup_truck, 6.4ms
# image 424/558 /content/yolov5/yolo_dataset/images/test/00004272.jpg: 448x640 1 car, 1 pickup_truck, 6.3ms
# image 425/558 /content/yolov5/yolo_dataset/images/test/00004273.jpg: 448x640 2 cars, 2 articulated_trucks, 6.4ms
# image 426/558 /content/yolov5/yolo_dataset/images/test/00004276.jpg: 448x640 1 car, 6.3ms
# image 427/558 /content/yolov5/yolo_dataset/images/test/00004295.jpg: 448x640 1 car, 6.4ms
# image 428/558 /content/yolov5/yolo_dataset/images/test/00004303.jpg: 448x640 5 cars, 4 pickup_trucks, 6.3ms
# image 429/558 /content/yolov5/yolo_dataset/images/test/00004304.jpg: 448x640 5 cars, 6.3ms
# image 430/558 /content/yolov5/yolo_dataset/images/test/00004310.jpg: 448x640 4 cars, 2 pickup_trucks, 6.6ms
# image 431/558 /content/yolov5/yolo_dataset/images/test/00004316.jpg: 448x640 1 car, 6.4ms
# image 432/558 /content/yolov5/yolo_dataset/images/test/00004324.jpg: 448x640 5 cars, 2 pickup_trucks, 6.4ms
# image 433/558 /content/yolov5/yolo_dataset/images/test/00004329.jpg: 448x640 (no detections), 6.4ms
# image 434/558 /content/yolov5/yolo_dataset/images/test/00004336.jpg: 448x640 1 car, 6.4ms
# image 435/558 /content/yolov5/yolo_dataset/images/test/00004351.jpg: 448x640 4 cars, 1 pickup_truck, 6.4ms
# image 436/558 /content/yolov5/yolo_dataset/images/test/00004360.jpg: 448x640 10 cars, 6.4ms
# image 437/558 /content/yolov5/yolo_dataset/images/test/00004361.jpg: 448x640 2 cars, 6.5ms
# image 438/558 /content/yolov5/yolo_dataset/images/test/00004390.jpg: 448x640 (no detections), 6.4ms
# image 439/558 /content/yolov5/yolo_dataset/images/test/00004405.jpg: 448x640 1 bus, 6.4ms
# image 440/558 /content/yolov5/yolo_dataset/images/test/00004427.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 441/558 /content/yolov5/yolo_dataset/images/test/00004444.jpg: 448x640 3 cars, 6.3ms
# image 442/558 /content/yolov5/yolo_dataset/images/test/00004469.jpg: 448x640 (no detections), 7.0ms
# image 443/558 /content/yolov5/yolo_dataset/images/test/00004472.jpg: 448x640 5 cars, 1 pickup_truck, 6.3ms
# image 444/558 /content/yolov5/yolo_dataset/images/test/00004474.jpg: 448x640 4 cars, 6.4ms
# image 445/558 /content/yolov5/yolo_dataset/images/test/00004492.jpg: 448x640 1 car, 6.5ms
# image 446/558 /content/yolov5/yolo_dataset/images/test/00004495.jpg: 448x640 3 cars, 6.4ms
# image 447/558 /content/yolov5/yolo_dataset/images/test/00004498.jpg: 448x640 5 cars, 1 pickup_truck, 6.3ms
# image 448/558 /content/yolov5/yolo_dataset/images/test/00004511.jpg: 448x640 3 cars, 6.4ms
# image 449/558 /content/yolov5/yolo_dataset/images/test/00004521.jpg: 448x640 3 cars, 6.4ms
# image 450/558 /content/yolov5/yolo_dataset/images/test/00004528.jpg: 448x640 3 cars, 6.4ms
# image 451/558 /content/yolov5/yolo_dataset/images/test/00004533.jpg: 448x640 2 cars, 1 bus, 6.4ms
# image 452/558 /content/yolov5/yolo_dataset/images/test/00004536.jpg: 448x640 7 cars, 1 pickup_truck, 6.4ms
# image 453/558 /content/yolov5/yolo_dataset/images/test/00004579.jpg: 448x640 2 cars, 1 pickup_truck, 6.4ms
# image 454/558 /content/yolov5/yolo_dataset/images/test/00004585.jpg: 448x640 2 cars, 6.4ms
# image 455/558 /content/yolov5/yolo_dataset/images/test/00004600.jpg: 448x640 7 cars, 2 pickup_trucks, 6.3ms
# image 456/558 /content/yolov5/yolo_dataset/images/test/00004601.jpg: 448x640 5 cars, 6.5ms
# image 457/558 /content/yolov5/yolo_dataset/images/test/00004609.jpg: 448x640 1 car, 6.5ms
# image 458/558 /content/yolov5/yolo_dataset/images/test/00004632.jpg: 448x640 8 cars, 6.5ms
# image 459/558 /content/yolov5/yolo_dataset/images/test/00004639.jpg: 448x640 3 cars, 2 pickup_trucks, 6.4ms
# image 460/558 /content/yolov5/yolo_dataset/images/test/00004649.jpg: 448x640 3 cars, 6.4ms
# image 461/558 /content/yolov5/yolo_dataset/images/test/00004658.jpg: 448x640 2 cars, 6.4ms
# image 462/558 /content/yolov5/yolo_dataset/images/test/00004663.jpg: 448x640 7 cars, 6.4ms
# image 463/558 /content/yolov5/yolo_dataset/images/test/00004680.jpg: 448x640 3 cars, 6.9ms
# image 464/558 /content/yolov5/yolo_dataset/images/test/00004681.jpg: 448x640 1 car, 2 pickup_trucks, 6.5ms
# image 465/558 /content/yolov5/yolo_dataset/images/test/00004682.jpg: 448x640 2 cars, 6.5ms
# image 466/558 /content/yolov5/yolo_dataset/images/test/00004684.jpg: 448x640 2 cars, 6.7ms
# image 467/558 /content/yolov5/yolo_dataset/images/test/00004688.jpg: 448x640 1 car, 6.5ms
# image 468/558 /content/yolov5/yolo_dataset/images/test/00004697.jpg: 448x640 2 cars, 1 pickup_truck, 6.5ms
# image 469/558 /content/yolov5/yolo_dataset/images/test/00004704.jpg: 448x640 3 cars, 1 bus, 6.4ms
# image 470/558 /content/yolov5/yolo_dataset/images/test/00004728.jpg: 448x640 1 car, 6.4ms
# image 471/558 /content/yolov5/yolo_dataset/images/test/00004733.jpg: 448x640 4 cars, 1 bus, 1 pickup_truck, 6.4ms
# image 472/558 /content/yolov5/yolo_dataset/images/test/00004748.jpg: 448x640 1 car, 6.4ms
# image 473/558 /content/yolov5/yolo_dataset/images/test/00004769.jpg: 448x640 2 cars, 6.4ms
# image 474/558 /content/yolov5/yolo_dataset/images/test/00004775.jpg: 448x640 5 cars, 6.4ms
# image 475/558 /content/yolov5/yolo_dataset/images/test/00004802.jpg: 448x640 3 cars, 6.4ms
# image 476/558 /content/yolov5/yolo_dataset/images/test/00004803.jpg: 448x640 3 cars, 1 pickup_truck, 6.4ms
# image 477/558 /content/yolov5/yolo_dataset/images/test/00004814.jpg: 448x640 2 cars, 1 bus, 6.4ms
# image 478/558 /content/yolov5/yolo_dataset/images/test/00004825.jpg: 448x640 (no detections), 6.5ms
# image 479/558 /content/yolov5/yolo_dataset/images/test/00004835.jpg: 448x640 4 cars, 6.7ms
# image 480/558 /content/yolov5/yolo_dataset/images/test/00004839.jpg: 448x640 4 cars, 1 pickup_truck, 6.7ms
# image 481/558 /content/yolov5/yolo_dataset/images/test/00004843.jpg: 448x640 4 cars, 1 pickup_truck, 6.4ms
# image 482/558 /content/yolov5/yolo_dataset/images/test/00004870.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 483/558 /content/yolov5/yolo_dataset/images/test/00004876.jpg: 448x640 3 cars, 6.4ms
# image 484/558 /content/yolov5/yolo_dataset/images/test/00004925.jpg: 448x640 3 cars, 1 bus, 1 pickup_truck, 6.4ms
# image 485/558 /content/yolov5/yolo_dataset/images/test/00004936.jpg: 448x640 13 cars, 1 pickup_truck, 6.4ms
# image 486/558 /content/yolov5/yolo_dataset/images/test/00004941.jpg: 448x640 1 car, 1 pickup_truck, 6.5ms
# image 487/558 /content/yolov5/yolo_dataset/images/test/00004965.jpg: 448x640 4 cars, 1 pickup_truck, 6.5ms
# image 488/558 /content/yolov5/yolo_dataset/images/test/00005000.jpg: 448x640 7 cars, 1 bus, 6.5ms
# image 489/558 /content/yolov5/yolo_dataset/images/test/00005013.jpg: 448x640 3 cars, 6.5ms
# image 490/558 /content/yolov5/yolo_dataset/images/test/00005032.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 491/558 /content/yolov5/yolo_dataset/images/test/00005044.jpg: 448x640 13 cars, 6.4ms
# image 492/558 /content/yolov5/yolo_dataset/images/test/00005063.jpg: 448x640 1 car, 6.4ms
# image 493/558 /content/yolov5/yolo_dataset/images/test/00005072.jpg: 448x640 3 cars, 6.4ms
# image 494/558 /content/yolov5/yolo_dataset/images/test/00005084.jpg: 448x640 2 cars, 6.4ms
# image 495/558 /content/yolov5/yolo_dataset/images/test/00005085.jpg: 448x640 7 cars, 6.4ms
# image 496/558 /content/yolov5/yolo_dataset/images/test/00005095.jpg: 448x640 4 cars, 6.4ms
# image 497/558 /content/yolov5/yolo_dataset/images/test/00005096.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 498/558 /content/yolov5/yolo_dataset/images/test/00005098.jpg: 448x640 2 cars, 6.4ms
# image 499/558 /content/yolov5/yolo_dataset/images/test/00005099.jpg: 448x640 7 cars, 1 bus, 6.4ms
# image 500/558 /content/yolov5/yolo_dataset/images/test/00005115.jpg: 448x640 3 cars, 6.5ms
# image 501/558 /content/yolov5/yolo_dataset/images/test/00005116.jpg: 448x640 2 cars, 1 articulated_truck, 1 pickup_truck, 6.5ms
# image 502/558 /content/yolov5/yolo_dataset/images/test/00005124.jpg: 448x640 1 car, 6.5ms
# image 503/558 /content/yolov5/yolo_dataset/images/test/00005130.jpg: 448x640 1 car, 6.4ms
# image 504/558 /content/yolov5/yolo_dataset/images/test/00005137.jpg: 448x640 2 cars, 6.4ms
# image 505/558 /content/yolov5/yolo_dataset/images/test/00005146.jpg: 448x640 1 pickup_truck, 6.4ms
# image 506/558 /content/yolov5/yolo_dataset/images/test/00005156.jpg: 448x640 1 car, 6.4ms
# image 507/558 /content/yolov5/yolo_dataset/images/test/00005170.jpg: 448x640 7 cars, 1 pickup_truck, 6.5ms
# image 508/558 /content/yolov5/yolo_dataset/images/test/00005180.jpg: 448x640 2 cars, 6.9ms
# image 509/558 /content/yolov5/yolo_dataset/images/test/00005195.jpg: 448x640 2 cars, 2 pickup_trucks, 6.4ms
# image 510/558 /content/yolov5/yolo_dataset/images/test/00005199.jpg: 448x640 6 cars, 6.4ms
# image 511/558 /content/yolov5/yolo_dataset/images/test/00005204.jpg: 448x640 5 cars, 1 bus, 6.4ms
# image 512/558 /content/yolov5/yolo_dataset/images/test/00005224.jpg: 448x640 21 cars, 6.4ms
# image 513/558 /content/yolov5/yolo_dataset/images/test/00005237.jpg: 448x640 2 cars, 1 pickup_truck, 6.4ms
# image 514/558 /content/yolov5/yolo_dataset/images/test/00005248.jpg: 448x640 (no detections), 6.4ms
# image 515/558 /content/yolov5/yolo_dataset/images/test/00005249.jpg: 448x640 1 car, 6.4ms
# image 516/558 /content/yolov5/yolo_dataset/images/test/00005278.jpg: 448x640 1 car, 6.4ms
# image 517/558 /content/yolov5/yolo_dataset/images/test/00005290.jpg: 448x640 (no detections), 6.4ms
# image 518/558 /content/yolov5/yolo_dataset/images/test/00005294.jpg: 448x640 2 cars, 6.4ms
# image 519/558 /content/yolov5/yolo_dataset/images/test/00005296.jpg: 448x640 (no detections), 6.5ms
# image 520/558 /content/yolov5/yolo_dataset/images/test/00005318.jpg: 448x640 9 cars, 1 articulated_truck, 6.5ms
# image 521/558 /content/yolov5/yolo_dataset/images/test/00005336.jpg: 448x640 (no detections), 6.5ms
# image 522/558 /content/yolov5/yolo_dataset/images/test/00005341.jpg: 448x640 2 cars, 6.4ms
# image 523/558 /content/yolov5/yolo_dataset/images/test/00005344.jpg: 448x640 2 cars, 1 bus, 6.6ms
# image 524/558 /content/yolov5/yolo_dataset/images/test/00005353.jpg: 448x640 2 cars, 6.6ms
# image 525/558 /content/yolov5/yolo_dataset/images/test/00005357.jpg: 448x640 7 cars, 2 pickup_trucks, 6.7ms
# image 526/558 /content/yolov5/yolo_dataset/images/test/00005372.jpg: 448x640 6 cars, 6.5ms
# image 527/558 /content/yolov5/yolo_dataset/images/test/00005375.jpg: 448x640 20 cars, 1 bus, 6.5ms
# image 528/558 /content/yolov5/yolo_dataset/images/test/00005377.jpg: 448x640 (no detections), 6.9ms
# image 529/558 /content/yolov5/yolo_dataset/images/test/00005382.jpg: 448x640 2 cars, 6.5ms
# image 530/558 /content/yolov5/yolo_dataset/images/test/00005388.jpg: 448x640 2 cars, 6.5ms
# image 531/558 /content/yolov5/yolo_dataset/images/test/00005403.jpg: 448x640 2 cars, 6.5ms
# image 532/558 /content/yolov5/yolo_dataset/images/test/00005405.jpg: 448x640 4 cars, 6.4ms
# image 533/558 /content/yolov5/yolo_dataset/images/test/00005418.jpg: 448x640 5 cars, 6.5ms
# image 534/558 /content/yolov5/yolo_dataset/images/test/00005424.jpg: 448x640 3 cars, 1 bus, 6.4ms
# image 535/558 /content/yolov5/yolo_dataset/images/test/00005425.jpg: 448x640 10 cars, 6.9ms
# image 536/558 /content/yolov5/yolo_dataset/images/test/00005428.jpg: 448x640 1 car, 6.5ms
# image 537/558 /content/yolov5/yolo_dataset/images/test/00005430.jpg: 448x640 1 pickup_truck, 6.5ms
# image 538/558 /content/yolov5/yolo_dataset/images/test/00005458.jpg: 448x640 1 car, 1 pickup_truck, 6.4ms
# image 539/558 /content/yolov5/yolo_dataset/images/test/00005461.jpg: 448x640 3 cars, 6.5ms
# image 540/558 /content/yolov5/yolo_dataset/images/test/00005472.jpg: 448x640 2 cars, 6.5ms
# image 541/558 /content/yolov5/yolo_dataset/images/test/00005477.jpg: 448x640 2 cars, 6.5ms
# image 542/558 /content/yolov5/yolo_dataset/images/test/00005496.jpg: 448x640 4 cars, 7.3ms
# image 543/558 /content/yolov5/yolo_dataset/images/test/00005503.jpg: 448x640 4 cars, 6.4ms
# image 544/558 /content/yolov5/yolo_dataset/images/test/00005506.jpg: 448x640 1 car, 1 pickup_truck, 6.3ms
# image 545/558 /content/yolov5/yolo_dataset/images/test/00005510.jpg: 448x640 4 cars, 1 articulated_truck, 6.3ms
# image 546/558 /content/yolov5/yolo_dataset/images/test/00005518.jpg: 448x640 1 car, 6.5ms
# image 547/558 /content/yolov5/yolo_dataset/images/test/00005540.jpg: 448x640 3 cars, 6.4ms
# image 548/558 /content/yolov5/yolo_dataset/images/test/00005553.jpg: 448x640 1 car, 6.4ms
# image 549/558 /content/yolov5/yolo_dataset/images/test/00005557.jpg: 448x640 2 cars, 6.4ms
# image 550/558 /content/yolov5/yolo_dataset/images/test/00005562.jpg: 448x640 8 cars, 6.4ms
# image 551/558 /content/yolov5/yolo_dataset/images/test/00005564.jpg: 448x640 2 cars, 2 pickup_trucks, 6.3ms
# image 552/558 /content/yolov5/yolo_dataset/images/test/00005568.jpg: 448x640 1 articulated_truck, 6.3ms
# image 553/558 /content/yolov5/yolo_dataset/images/test/00005571.jpg: 448x640 2 cars, 6.3ms
# image 554/558 /content/yolov5/yolo_dataset/images/test/00005572.jpg: 448x640 1 car, 6.4ms
# image 555/558 /content/yolov5/yolo_dataset/images/test/00005576.jpg: 448x640 1 car, 1 pickup_truck, 6.3ms
# image 556/558 /content/yolov5/yolo_dataset/images/test/00005594.jpg: 448x640 1 car, 6.3ms
# image 557/558 /content/yolov5/yolo_dataset/images/test/00005613.jpg: 448x640 2 cars, 1 pickup_truck, 6.4ms
# image 558/558 /content/yolov5/yolo_dataset/images/test/00005636.jpg: 448x640 2 cars, 1 bus, 1 pickup_truck, 6.4ms
# Speed: 0.4ms pre-process, 6.5ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/yolov5/runs/detect/inference_2
# Attempting to visualize images from: /content/yolov5/runs/detect/inference_2
# Found inference images: 558
# Displaying the 3 images out of 558.
# Figure(1000x1000)
# Figure(1000x1000)
# Figure(1000x1000)
#
# Script execution finished!

# %% [markdown]
# #Evaluate the model and check the test results

# %%
import os
# %cd /content/yolov5/runs/train/my_custom_run
#!ls -lh
# Out:
# /content/yolov5/runs/train/my_custom_run

# %%
from IPython.display import Image, display
display(Image(filename='/content/yolov5/runs/train/my_custom_run/results.png', width=1000))

# %%
display(Image(filename='/content/yolov5/runs/train/my_custom_run/confusion_matrix.png', width=800))

# %% [markdown]
# # Confusion Matrix Interpretation:
# - 86% of actual buses are correctly identified (Predicted: bus, True: bus is 0.86)
# - 51% of actual pickup trucks are correctly identified (Predicted: pickup_truck, True: pickup_truck is 0.51)
# - 51% of actual pickup trucks are correctly identified (Predicted: pickup_truck, True: pickup_truck is 0.51)

# %%
display(Image(filename='/content/yolov5/runs/train/my_custom_run/PR_curve.png', width=800))

# %% [markdown]
# # Evaluation conclusion:
# - Model performed exceptionally well at bus, car and pickup_truck detection with the highest Average Precision(AP).
# - The model has moderately identified the Articulated_truck at 0.310 AP.
# - It has performed poorly for other classes
#
# ##Summary
#
# An mAP@0.5 of 0.288 (28.8%) suggests that, on average, your model's - performance for detecting all classes at an IoU of 0.5 is fair but indicates considerable room for improvement. The performance is heavily skewed by the strong detection of 'bus' and 'car', while other classes are detected very poorly.

# %% [markdown]
# #Run inferences on sample images and see if vehicles are detected accurately

# %%
import os
import cv2
import matplotlib.pyplot as plt
import glob
from IPython.display import Image, display

# --- Set variable for the directory ---
INFER_RESULTS_DIR = '/content/yolov5/runs/detect/inference_1'

if not os.path.exists(INFER_RESULTS_DIR):
    print(f"Inference results directory not found: {INFER_RESULTS_DIR}")
else:
    print(f"Listing contents of: {INFER_RESULTS_DIR}")
    #!ls "{INFER_RESULTS_DIR}"

    infer_images = glob.glob(f"{INFER_RESULTS_DIR}/*.jpg") # Assuming .jpg outputs
    print(f"Found {len(infer_images)} inference images for display.")

    if not infer_images:
        print(f"No .jpg images found in {INFER_RESULTS_DIR}.")
    else:
        # Displaying a subset (first 3 images)
        limit = 10 # Define the limit here
        images_to_display = infer_images[:limit] # Slice the list
        print(f"Displaying {len(images_to_display)} out of {len(infer_images)} inference images.")

        for i, pred_image_path in enumerate(images_to_display): # Iterate over the limited list
            #print(f"Displaying: {os.path.basename(pred_image_path)}") # Uncomment if you want individual image filenames
            # For displaying in Colab (optional, but often preferred for many images):
            #display(Image(filename=pred_image_path, width=500)) # Adjust width as needed

            # Using matplotlib for more control, as in your original code:
            image = cv2.imread(pred_image_path)
            if image is not None:
                plt.figure(figsize=(8, 8))
                plt.imshow(image[:, :, ::-1]) # Convert BGR to RGB for matplotlib
                plt.axis('off')
                plt.title(os.path.basename(pred_image_path))
                plt.show()
            else:
                print(f"Warning: Could not read image {pred_image_path}.")

        if len(infer_images) > limit: # Adjust the condition based on 'limit'
            print(f"\n... and {len(infer_images) - limit} more images. Adjust the display loop to see all.")
# Out:
# Listing contents of: /content/yolov5/runs/detect/inference_1
# Found 558 inference images for display.
# Displaying 10 out of 558 inference images.
# ... and 548 more images. Adjust the display loop to see all.
